# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/DSLab2"
# Out:
#  Ablation    DeepSKAN_MSL_Qualitative_Analysis.ipynb   Untitled0.ipynb
#  Baselines  'Hybrid Model (Alpha Tuned)'

# %%
# !git clone https://github.com/Chiimaa/DeepSKAN
# Out:
# Cloning into 'DeepSKAN'...
# ...

# %%
# !ls
# Out:
# DeepSKAN  drive  sample_data

# %%
# %cd DeepSKAN
# Out:
# /content/DeepSKAN
